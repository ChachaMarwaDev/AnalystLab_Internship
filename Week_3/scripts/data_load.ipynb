# %% [markdown]
# # Sales Dataset (AdventureWorks Lite / Equivalent)

# %%
import pandas as pd
import kagglehub as ka
import numpy as np
from sqlalchemy import create_engine

# %%
# Download the dataset directly to the 'data' directory, run it once
path = ka.dataset_download("kyanyoga/sample-sales-data", output_dir="../data")

# %%
import pandas as pd
from sqlalchemy import create_engine

# Load your CSV
df = pd.read_csv("../data/sales_data_sample.csv", encoding='cp1252')

# Connect to Postgres running in Docker
engine = create_engine("postgresql://postgres:yourpassword@localhost:5432/sales_db")

# Push it into a table called "sales"
df.to_sql("sales", engine, if_exists="replace", index=False)

print("Loaded successfully!")

# %% [markdown]
# ## Practice

# %%
df.columns.tolist()
len(df)
