# %% [markdown]
# # E-commerce Transactions Dataset

# %%
# Definition for getting the data and modules
import pandas as pd
import kagglehub as ka
import numpy as np
import chardet

url_path = 'https://www.kaggle.com/datasets/vijayuv/onlineretail'
data_path = "../data/online_retail/OnlineRetail.csv"

# %%
# Download the dataset directly to the 'data' directory
path = ka.dataset_download("vijayuv/onlineretail", output_dir="../data/online_retail")

# %%
try:
    df = pd.read_csv("../data/online_retail/OnlineRetail.csv", encoding='cp1252')
    print("Successfully loaded with cp1252 encoding")
except:
    df = pd.read_csv("../data/online_retail/OnlineRetail.csv", encoding='latin-1')
    print("Successfully loaded with latin-1 encoding")
# Out:
# Successfully loaded with cp1252 encoding

# %%
# Displaying the first and last rows
print(df.head(5))
print(df.tail(5))
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# ...
