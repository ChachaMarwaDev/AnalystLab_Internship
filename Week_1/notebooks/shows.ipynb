# %% [markdown]
# # Netflix Movies & TV Shows Dataset

# %% [markdown]
# ## Load the dataset into Python

# %%
# Definition for getting the data
URL='https://www.kaggle.com/datasets/shivamb/netflix-shows'

print(URL)
# Out:
# Running cells with '.venv (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/dev/AnalystLab_Internship/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
